# %% [markdown]
# <a href="https://colab.research.google.com/github/Psalmist70/fraud-detection-system/blob/main/notebooks_fraud_model_development.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
